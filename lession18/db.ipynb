# %%
import sqlite3
from sqlite3 import Error

try:
    conn = sqlite3.connect('./data/pico_db.db')
except Exception as e:
    print(e)

# %%
sql = """
    INSERT INTO 雞舍(時間,設備,值)
    VALUES(?,?,?)
    """
cursor = conn.cursor()
cursor.execute(sql,('2024-10-12 16:14:06','SA-23/LED_LEVEL',16.8))
conn.commit()
cursor.close()
conn.close()

# %%
conn
